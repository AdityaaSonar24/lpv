# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
train_df = pd.read_csv('Google_Stock_Price_Train.csv')
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1258 non-null   object
#  1   Open    1258 non-null   float64
#  2   High    1258 non-null   float64
#  3   Low     1258 non-null   float64
#  4   Close   1258 non-null   object
#  5   Volume  1258 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 59.1+ KB

# %%
test_df = pd.read_csv('Google_Stock_Price_Test.csv')
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    20 non-null     object
#  1   Open    20 non-null     float64
#  2   High    20 non-null     float64
#  3   Low     20 non-null     float64
#  4   Close   20 non-null     float64
#  5   Volume  20 non-null     object
# dtypes: float64(4), object(2)
# memory usage: 1.1+ KB

# %%
#Choosing column 'open' for predicition
train = train_df.loc[:,["Open"]].values
train.shape
# Out:
# (1258, 1)

# %%
#Feature Scaling
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
train_scaled = scaler.fit_transform(train)

# %%
plt.plot(train_scaled)
plt.ylabel("Standardized Values")
plt.xlabel("Time->")
plt.show()

# %%
#Create data structure to train model
x_train = []
y_train = []
time = 60
for i in range(60,train_scaled.shape[0]):
    x_train.append(train_scaled[i-60:i,0])
    y_train.append(train_scaled[i,0])
x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
x_train.shape,y_train.shape
# Out:
# ((1198, 60), (1198,))

# %%
x_train = np.reshape(x_train,newshape=(x_train.shape[0],x_train.shape[1],1))
x_train.shape
# Out:
# (1198, 60, 1)

# %%
#Build model
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN,Dropout

# %%
model = Sequential()

model.add(SimpleRNN(units=50,activation = "tanh", return_sequences = True, input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50,activation = "tanh", return_sequences = True))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50,activation = "tanh", return_sequences = True))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50))
model.add(Dropout(0.2))

model.add(Dense(units=1))

model.compile(optimizer='adam',loss='mse')
model.summary()
# Out:
# C:\Users\Vikas Deore\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)               │ (None, 60, 50)              │           2,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 60, 50)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_1 (SimpleRNN)             │ (None, 60, 50)              │           5,050 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 60, 50)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_2 (SimpleRNN)             │ (None, 60, 50)              │           5,050 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 60, 50)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_3 (SimpleRNN)             │ (None, 50)                  │           5,050 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 17,801 (69.54 KB)
#  Trainable params: 17,801 (69.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x_train,y_train,epochs=100,batch_size=30,validation_split=0.05)
# Out:
# Epoch 1/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - loss: 0.5224 - val_loss: 0.0312
# Epoch 2/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.2684 - val_loss: 0.0259
# Epoch 3/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.1910 - val_loss: 0.0046
# Epoch 4/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.1517 - val_loss: 0.0236
# Epoch 5/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.1175 - val_loss: 0.0621
# Epoch 6/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0980 - val_loss: 0.0607
# Epoch 7/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0776 - val_loss: 0.0044
# Epoch 8/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0621 - val_loss: 0.0023
# Epoch 9/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0547 - val_loss: 0.0054
# Epoch 10/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0472 - val_loss: 0.0192
# Epoch 11/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0381 - val_loss: 0.0213
# Epoch 12/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0333 - val_loss: 0.0039
# Epoch 13/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0331 - val_loss: 0.0155
# Epoch 14/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0273 - val_loss: 0.0046
# Epoch 15/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0259 - val_loss: 0.0076
# Epoch 16/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0235 - val_loss: 0.0073
# Epoch 17/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0189 - val_loss: 0.0070
# Epoch 18/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0213 - val_loss: 0.0110
# Epoch 19/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0186 - val_loss: 0.0036
# Epoch 20/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0184 - val_loss: 0.0240
# Epoch 21/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0156 - val_loss: 0.0038
# Epoch 22/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0130 - val_loss: 7.5237e-04
# Epoch 23/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0124 - val_loss: 4.7407e-04
# Epoch 24/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0124 - val_loss: 0.0127
# Epoch 25/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0115 - val_loss: 5.0532e-04
# Epoch 26/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0102 - val_loss: 0.0052
# Epoch 27/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0106 - val_loss: 0.0032
# Epoch 28/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0087 - val_loss: 6.3626e-04
# Epoch 29/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0090 - val_loss: 5.2569e-04
# Epoch 30/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0084 - val_loss: 0.0027
# Epoch 31/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0076 - val_loss: 0.0079
# Epoch 32/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0078 - val_loss: 0.0019
# Epoch 33/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0075 - val_loss: 0.0025
# Epoch 34/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0066 - val_loss: 0.0032
# Epoch 35/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0068 - val_loss: 0.0028
# Epoch 36/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 37/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0057 - val_loss: 0.0041
# Epoch 38/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0063 - val_loss: 5.3878e-04
# Epoch 39/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0058 - val_loss: 0.0024
# Epoch 40/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0051 - val_loss: 5.0682e-04
# Epoch 41/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0051 - val_loss: 0.0031
# Epoch 42/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0062 - val_loss: 5.5459e-04
# Epoch 43/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0052 - val_loss: 0.0027
# Epoch 44/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0050 - val_loss: 0.0011
# Epoch 45/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0047 - val_loss: 5.6450e-04
# Epoch 46/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0042 - val_loss: 0.0026
# Epoch 47/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0045 - val_loss: 6.1391e-04
# Epoch 48/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0045 - val_loss: 9.9772e-04
# Epoch 49/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0040 - val_loss: 0.0010
# Epoch 50/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0044 - val_loss: 5.6599e-04
# Epoch 51/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0041 - val_loss: 0.0015
# Epoch 52/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0037 - val_loss: 0.0015
# Epoch 53/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0040 - val_loss: 5.1640e-04
# Epoch 54/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0038 - val_loss: 6.2116e-04
# Epoch 55/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0033 - val_loss: 6.0068e-04
# Epoch 56/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0034 - val_loss: 5.0149e-04
# Epoch 57/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0032 - val_loss: 6.1935e-04
# Epoch 58/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0032 - val_loss: 0.0016
# Epoch 59/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0037 - val_loss: 6.6060e-04
# Epoch 60/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0033 - val_loss: 9.8482e-04
# Epoch 61/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0031 - val_loss: 6.9363e-04
# Epoch 62/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0030 - val_loss: 0.0017
# Epoch 63/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0031 - val_loss: 5.8594e-04
# Epoch 64/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0034 - val_loss: 7.7516e-04
# Epoch 65/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0027 - val_loss: 6.0646e-04
# Epoch 66/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0027 - val_loss: 0.0015
# Epoch 67/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0030 - val_loss: 4.9411e-04
# Epoch 68/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0026 - val_loss: 0.0043
# Epoch 69/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0036 - val_loss: 6.2989e-04
# Epoch 70/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0032 - val_loss: 6.1692e-04
# Epoch 71/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 72/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 73/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0027 - val_loss: 5.3618e-04
# Epoch 74/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0027 - val_loss: 4.5960e-04
# Epoch 75/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0027 - val_loss: 9.1679e-04
# Epoch 76/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 77/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0026 - val_loss: 6.0780e-04
# Epoch 78/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 79/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0024 - val_loss: 5.8182e-04
# Epoch 80/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0027 - val_loss: 5.0147e-04
# Epoch 81/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0023 - val_loss: 7.2435e-04
# Epoch 82/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0025 - val_loss: 8.6193e-04
# Epoch 83/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0026 - val_loss: 4.6354e-04
# Epoch 84/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0022 - val_loss: 4.8184e-04
# Epoch 85/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0022 - val_loss: 7.2807e-04
# Epoch 86/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0022 - val_loss: 4.9545e-04
# Epoch 87/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 88/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0023 - val_loss: 5.0335e-04
# Epoch 89/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0024 - val_loss: 6.6092e-04
# Epoch 90/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0020 - val_loss: 4.7004e-04
# Epoch 91/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0021 - val_loss: 7.2911e-04
# Epoch 92/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0019 - val_loss: 5.0165e-04
# Epoch 93/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0018 - val_loss: 4.4378e-04
# Epoch 94/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0020 - val_loss: 9.6560e-04
# Epoch 95/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0018 - val_loss: 4.5333e-04
# Epoch 96/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0021 - val_loss: 6.3708e-04
# Epoch 97/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0021 - val_loss: 6.1951e-04
# Epoch 98/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0018 - val_loss: 8.7783e-04
# Epoch 99/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0020 - val_loss: 6.3452e-04
# Epoch 100/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0019 - val_loss: 4.7220e-04

# %%
#Prepare test dataset
data = pd.concat((train_df['Open'],test_df['Open']),axis=0)

# %%
test_input = data.iloc[len(data) - len(test_df) - time : ].values
test_input.shape
# Out:
# (80,)

# %%
test_input = test_input.reshape(-1,1)
test_input.shape
# Out:
# (80, 1)

# %%
test_scaled = scaler.transform(test_input)

# %%
#Create test data set
x_test = []
for i in range(time,test_scaled.shape[0]):
    x_test.append(test_scaled[i - time: i,0 ])
x_test = np.array(x_test)
x_test.shape
# Out:
# (20, 60)

# %%
x_test = np.reshape(x_test,newshape=(x_test.shape[0],x_test.shape[1],1))
x_test.shape
# Out:
# (20, 60, 1)

# %%
y_test = test_df.loc[:,"Open"].values

# %%
#Model Prediction
y_pred = model.predict(x_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 808ms/step

# %%
y_pred = scaler.inverse_transform(y_pred)

# %%
output = model.evaluate(x=x_test,y=y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 982ms/step - loss: 650766.6250

# %%
plt.plot(y_test, color = 'red', label = 'Real price')
plt.plot(y_pred, color = 'blue', label = 'Predicted price')

plt.title('Google Stock price prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
